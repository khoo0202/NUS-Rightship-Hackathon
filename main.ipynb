# %%
# Basic Libraries
import numpy as np
import pandas as pd
import datetime
#test comment

# %%
df = pd.read_csv('vessel_movements_PPT.csv')

# %%
df.head()
# Out:
#              imo       mmsi  vessel_id        vessel_name date_of_build  \
# 0        9223253  525119038     692017  PRIMA TANGGUH LVI    2002-04-01
# 1        9223253  525119038     692017  PRIMA TANGGUH LVI    2002-04-01
# 2        9223253  525119038     692017  PRIMA TANGGUH LVI    2002-04-01
# 3        9223253  525119038     692017  PRIMA TANGGUH LVI    2002-04-01
# 4        9223253  525119038     692017  PRIMA TANGGUH LVI    2002-04-01
# ...          ...        ...        ...                ...           ...
# 2822594  9708693  374766000     714547          MSC CLARA    2015-11-01
# 2822595  9708693  374766000     714547          MSC CLARA    2015-11-01
# 2822596  9449106  636020361     647347        MENDELSSOHN    2012-04-01
# 2822597  9449106  636020361     647347        MENDELSSOHN    2012-04-01
# 2822598  9450313  636091832     647462  Northern Priority    2009-10-01
#
#                              vessel_type                    group  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822599 entries, 0 to 2822598
# Data columns (total 32 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   imo                    int64
#  1   mmsi                   int64
#  2   vessel_id              int64
#  3   vessel_name            object
#  4   date_of_build          object
#  5   vessel_type            object
#  6   group                  object
#  7   timestamp              object
#  8   date_only              object
#  9   lon                    float64
#  10  lat                    float64
#  11  nav_stat               int64
#  12  speed                  float64
#  13  course                 float64
#  14  heading                float64
#  15  fuel_category          int64
#  16  main_engine_fuel_type  object
#  17  aux_engine_fuel_type   object
#  18  engine_type            object
#  19  berth                  object
#  20  port_name              object
# ...

# %%
df.shape

# %%
df["imo"].nunique()

# %%
df["emi_tier"] = 0

# %%
df['date_of_build'] = pd.to_datetime(df['date_of_build'], format="%Y-%m-%d")

# Define the reference date as a datetime object
reference1 = datetime.datetime(2016, 1, 1)
reference2 = datetime.datetime(2011, 1, 1)
reference3 = datetime.datetime(2000, 1, 1)

df.loc[(df['date_of_build'] >= reference1),"emi_tier"] = 1
df.loc[((df['date_of_build'] > reference2)&(df['date_of_build'] < reference1)),"emi_tier"] = 2
df.loc[((df['date_of_build'] > reference3)&(df['date_of_build'] < reference2)),"emi_tier"] = 3
df

# %%
df['date_of_build'] = pd.to_datetime(df['date_of_build'], format="%Y-%m-%d")
df.head(100)

# %%
df1 = pd.read_csv('propulsion_engine_emission_factors.csv')
df2 = pd.read_csv('boiler_engine_emission_factors.csv')
df3 = pd.read_csv('auxiliary_engine_emission_factors.csv')

# %%
df["vessel_type"].value_counts()

# %%
l_1 = ["Container Ship (Fully Cellular)","Chemical/Products Tanker","Products Tanker","Bunkering Tanker","Asphalt/Bitumen Tanker","General Cargo Ship","Passenger Ship","Crude/Oil Products Tanker","Bulk Carrier","Crude Oil Tanker","Refrigerated Cargo Ship","Fish Carrier","Chemical Tanker","Passenger/Cruise","Passenger/Ro-Ro Ship (Vehicles)","Ro-Ro Cargo Ship","LPG Tanker","Buoy Tender","Passenger/Landing Craft","Aggregates Carrier","General Cargo Ship (with Ro-Ro facility)","LPG/Chemical Tanker"]

# %%
df["require"] = False
df.loc[df["vessel_type"].isin(l_1),"require"]=True
df

# %%
df.loc[df["require"]==False]

# %%
df = df.drop(df.loc[df["vessel_type"]==False].index,axis = 0)
df

# %%
df.to_csv("step3.csv",index = False)
